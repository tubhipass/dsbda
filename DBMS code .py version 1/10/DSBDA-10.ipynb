# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
info = pd.read_csv("IRIS.csv")

# %%
info.head(100)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
info.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28152\3443253950.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   info.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
info.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28152\1238929223.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   info.median()
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
info.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
info.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
info.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
info.var()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_28152\666572388.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   info.var()
# Id               1887.500000
# SepalLengthCm       0.685694
# SepalWidthCm        0.188004
# PetalLengthCm       3.113179
# PetalWidthCm        0.582414
# dtype: float64

# %%
plt.figure(figsize = (10, 7))
x = info["SepalLengthCm"]

plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10, 7))
x = info["SepalWidthCm"]

plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Width in cm")
plt.xlabel("Sepal_Width_cm")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10, 7))
x = info["PetalLengthCm"]

plt.hist(x, bins = 20, color = "green")
plt.title("Petal Length in cm")
plt.xlabel("Petal_Length_cm")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize = (10, 7))
x = info["PetalWidthCm"]

plt.hist(x, bins = 20, color = "green")
plt.title("Petal Width in cm")
plt.xlabel("Petal_Width_cm")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize = (8, 4))
info.boxplot()
plt.show()

# %%
fig, axes=plt.subplots(2, 2, figsize=(16, 8))
axes[0,0].set_title("Distribution of sepal length")
axes[0,0].hist(info["SepalLengthCm"]);

axes[0,1].set_title("Distribution of sepal width")
axes[0,1].hist(info["SepalWidthCm"]);

axes[1,0].set_title("Distribution of petal length")
axes[1,0].hist(info["PetalLengthCm"]);

axes[1,1].set_title("Distribution of petal width")
axes[1,1].hist(info["PetalWidthCm"]);
plt.show()

# %%
fig, axes=plt.subplots(2, 2, figsize=(16, 9))
axes[0,0].set_title("Distribution of sepal length")
sns.boxplot( y="SepalLengthCm", x="Species", data=info, orient='v', ax=axes[0,0])
axes[0,1].set_title("Distribution of sepal width")
sns.boxplot( y="SepalWidthCm", x="Species", data=info, orient='v', ax=axes[0,1])
axes[1,0].set_title("Distribution of petal length")
sns.boxplot( y="PetalLengthCm", x="Species", data=info, orient='v', ax=axes[1,0])
axes[1,1].set_title("Distribution of petal width")
sns.boxplot( y="PetalWidthCm", x="Species", data=info, orient='v', ax=axes[1,1])
plt.show()
